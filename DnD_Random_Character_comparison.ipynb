# %%
import pandas as pd

# %%
#D&D Random Player comps csv
Dnd_csv = "DnD_Chrctr_Comps.csv"

# %%
DnD_Random_Character_all_df = pd.read_csv(Dnd_csv, encoding="UTF-8")

# %%
DnD_Random_Character_all_df.head()
# Out:
#       First        Last      Class  Level                Race  Age  Ht (cm)  \
# 0     Adrik  Brewfinger       Monk      1          Hill Dwarf  244      137
# 1     Brocc      Fimebs  Barbarian      1        Forest Gnome   61       99
# 2  Kanithar       Chien  Barbarian      1               Human   22      163
# 3     Brocc      Nackle     Cleric      1          Rock Gnome   84      102
# 4    Merric    Goodbody    Paladin      1  Lightfoot Halfling   26       76
#
#    Wt (kg)  ArmC  Initv  ...  Med  Prcp  Surv  Chrsm  ChrsmB  Dec  Intmd  \
# 0       72    14      2  ...    2     2     2     13       1    1      1
# 1       21    15      2  ...    1     3     3     12       1    1      1
# 2       85    13      1  ...    2     2     0     10       0    0      0
# 3       22    18      1  ...    4     4     4     11       0    2      0
# 4       19    18      0  ...   -1     1    -1     16       3    3      3
#
#    Perfo  Persu  PartyNo
# 0      1      1        1
# ...

# %%
DnD_Random_Character_all_df.dtypes
# Out:
# First      object
# Last       object
# Class      object
# Level       int64
# Race       object
# Age         int64
# Ht (cm)     int64
# Wt (kg)     int64
# ArmC        int64
# Initv       int64
# Spd         int64
# HP          int64
# Prfc        int64
# Str         int64
# StrB        int64
# Athl        int64
# Dex         int64
# DexB        int64
# Acro        int64
# SoH         int64
# Stl         int64
# Const       int64
# ConstB      int64
# Intel       int64
# IntelB      int64
# Arca        int64
# Hst         int64
# Invst       int64
# Ntr         int64
# Rlgn        int64
# Wis         int64
# WisB        int64
# AnmH        int64
# Insgt       int64
# Med         int64
# Prcp        int64
# Surv        int64
# Chrsm       int64
# ChrsmB      int64
# Dec         int64
# Intmd       int64
# Perfo       int64
# Persu       int64
# PartyNo     int64
# dtype: object

# %%
demographic_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Level", "Race", "Age", "Ht (cm)", "Wt (kg)"
]]

# %%
demographic_df.head()
# Out:
#       First        Last      Class  Level                Race  Age  Ht (cm)  \
# 0     Adrik  Brewfinger       Monk      1          Hill Dwarf  244      137
# 1     Brocc      Fimebs  Barbarian      1        Forest Gnome   61       99
# 2  Kanithar       Chien  Barbarian      1               Human   22      163
# 3     Brocc      Nackle     Cleric      1          Rock Gnome   84      102
# 4    Merric    Goodbody    Paladin      1  Lightfoot Halfling   26       76
#
#    Wt (kg)
# 0       72
# 1       21
# 2       85
# 3       22
# 4       19

# %%
core_stats_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "ArmC", "Initv", "Spd", "HP"
]]

# %%
core_stats_df.head()
# Out:
#       First        Last      Class                Race  ArmC  Initv  Spd  HP
# 0     Adrik  Brewfinger       Monk          Hill Dwarf    14      2   25  11
# 1     Brocc      Fimebs  Barbarian        Forest Gnome    15      2   25  14
# 2  Kanithar       Chien  Barbarian               Human    13      1   30  14
# 3     Brocc      Nackle     Cleric          Rock Gnome    18      1   25  10
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling    18      0   25  10

# %%
strength_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Str", "StrB", "Athl"
]]

# %%
strength_df.head()
# Out:
#       First        Last      Class                Race  Str  StrB  Athl
# 0     Adrik  Brewfinger       Monk          Hill Dwarf   12     1     1
# 1     Brocc      Fimebs  Barbarian        Forest Gnome   16     3     5
# 2  Kanithar       Chien  Barbarian               Human   11     0     2
# 3     Brocc      Nackle     Cleric          Rock Gnome   16     3     3
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling   15     2     4

# %%
dexterity_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Dex", "DexB", "Acro", "SoH", "Stl"
]]

# %%
dexterity_df.head()
# Out:
#       First        Last      Class                Race  Dex  DexB  Acro  SoH  \
# 0     Adrik  Brewfinger       Monk          Hill Dwarf   15     2     4    4
# 1     Brocc      Fimebs  Barbarian        Forest Gnome   15     2     2    2
# 2  Kanithar       Chien  Barbarian               Human   12     1     1    1
# 3     Brocc      Nackle     Cleric          Rock Gnome   12     1     1    1
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling   10     0     0    0
#
#    Stl
# 0    4
# 1    2
# 2    1
# 3    3
# 4    0

# %%
constitution_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Const", "ConstB"
]]

# %%
constitution_df.head()
# Out:
#       First        Last      Class                Race  Const  ConstB
# 0     Adrik  Brewfinger       Monk          Hill Dwarf     15       2
# 1     Brocc      Fimebs  Barbarian        Forest Gnome     16       3
# 2  Kanithar       Chien  Barbarian               Human     15       2
# 3     Brocc      Nackle     Cleric          Rock Gnome     15       2
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling     11       0

# %%
intelligence_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Intel", "IntelB", "Arca", "Hst", "Invst", "Ntr", "Rlgn"
]]

# %%
intelligence_df.head()
# Out:
#       First        Last      Class                Race  Intel  IntelB  Arca  \
# 0     Adrik  Brewfinger       Monk          Hill Dwarf     12       1     1
# 1     Brocc      Fimebs  Barbarian        Forest Gnome     14       2     2
# 2  Kanithar       Chien  Barbarian               Human      7      -2    -2
# 3     Brocc      Nackle     Cleric          Rock Gnome      9      -1    -1
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling      6      -2    -2
#
#    Hst  Invst  Ntr  Rlgn
# 0    1      1    1     3
# 1    2      2    2     2
# 2    0     -2   -2     0
# 3   -1     -1   -1    -1
# 4   -2     -2   -2     0

# %%
wisdom_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Wis", "WisB", "AnmH", "Insgt", "Med", "Prcp", "Surv"
]]

# %%
wisdom_df.head()
# Out:
#       First        Last      Class                Race  Wis  WisB  AnmH  \
# 0     Adrik  Brewfinger       Monk          Hill Dwarf   15     2     2
# 1     Brocc      Fimebs  Barbarian        Forest Gnome   12     1     3
# 2  Kanithar       Chien  Barbarian               Human   11     0     0
# 3     Brocc      Nackle     Cleric          Rock Gnome   18     4     4
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling    9    -1    -1
#
#    Insgt  Med  Prcp  Surv
# 0      2    2     2     2
# 1      1    1     3     3
# 2      0    2     2     0
# 3      6    4     4     4
# 4      1   -1     1    -1

# %%
charisma_df = DnD_Random_Character_all_df.loc[0:20, [
    "First", "Last", "Class", "Race", "Chrsm", "ChrsmB", "Dec", "Intmd", "Perfo", "Persu"
]]

# %%
charisma_df.head()
# Out:
#       First        Last      Class                Race  Chrsm  ChrsmB  Dec  \
# 0     Adrik  Brewfinger       Monk          Hill Dwarf     13       1    1
# 1     Brocc      Fimebs  Barbarian        Forest Gnome     12       1    1
# 2  Kanithar       Chien  Barbarian               Human     10       0    0
# 3     Brocc      Nackle     Cleric          Rock Gnome     11       0    2
# 4    Merric    Goodbody    Paladin  Lightfoot Halfling     16       3    3
#
#    Intmd  Perfo  Persu
# 0      1      1      1
# 1      1      1      1
# 2      0      0      0
# 3      0      0      2
# 4      3      3      3
